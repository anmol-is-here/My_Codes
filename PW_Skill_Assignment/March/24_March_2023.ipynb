# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
wine = pd.read_csv('winequality-red.csv')
stud = pd.read_csv('stud.csv')

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides
# 0            7.4              0.70         0.00             1.9      0.076  \
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates
# 0                 11.0                  34.0   0.9978  3.51       0.56  \
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
stud.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch
# 0  female        group B           bachelor's degree      standard  \
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ## ANSWER-1

# %%
sns.heatmap(wine.corr())
# Out:
# <Axes: >

# %% [markdown]
# In order to **predict the quality of wine** the most important features are alcohol, sulphates, citric acid, fixed acidity, volatile acidity.
# Because their correlation with quality feature is high either positively or negatively.

# %% [markdown]
# Here are some of the key features of the wine quality dataset and their importance in predicting the quality of wine:-
#
# 1. **Citric acid:** It is a weak organic acid found in citrus fruits. It is added to wine during the winemaking process to balance the pH level. It is important in predicting wine quality because it can help to enhance the freshness and fruitiness of the wine
# 2. **Residual sugar:** It refers to the amount of sugar remaining in the wine after the fermentation process. It is important in predicting wine quality because it can affect the sweetness of the wine and can help to balance out the acidity.
# 3. **Chlorides:** It refers to the amount of salt in the wine. High levels of chloride can result in a salty taste. It is important in predicting wine quality because it can help to identify wines that are overly salty or unbalanced.
# 4. **pH:** It is a measure of the acidity or basicity of the wine. It is important in predicting wine quality because it can help to ensure that the wine is balanced and has a pleasant taste.
# 5. **Sulphates:** It refers to the amount of sulfates present in the wine. Sulfates act as a preservative and help to prevent spoilage. It is important in predicting wine quality because it can help to ensure that the wine is stable and will not spoil.
# 6. **Alcohol:** It is a measure of the percentage of alcohol in the wine. It is important in predicting wine quality because it can affect the taste and body of the wine. Higher levels of alcohol can result in a stronger and more full-bodied wine.
# 7. **Quality:** It is the dependent variable and is a measure of the overall quality of the wine. It is important in predicting wine quality because it is the target variable and is what we are trying to predict using the other attributes of the wine.

# %% [markdown]
# ## ANSWER-2

# %%
wine.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# - currently there is no missing value in wine dataset.
# #### missing values can be handled by computing mean, median, mode and k-nearest value
# The advantages and disadvantages of some imputation techniques are stated below:
#
# - Mean imputation:-
# Mean imputation involves replacing missing values with the mean value of the variable. This technique is simple and easy to implement. However, mean imputation may lead to biased estimates if the missing data are not missing at random. Mean imputation also reduces the variance of the variable, which may lead to underestimation of the standard errors and confidence intervals.
#
# - Median imputation:-
# Median imputation involves replacing missing values with the median value of the variable. This technique is also simple and easy to implement. Median imputation is more robust to outliers than mean imputation, and it does not change the variance of the variable. However, like mean imputation, median imputation may lead to biased estimates if the missing data are not missing at random.
#
# - K-nearest neighbor imputation:-
# K-nearest neighbor imputation involves replacing missing values with values from the K most similar cases in the dataset. This technique is more sophisticated than mean or median imputation and may produce more accurate estimates. K-nearest neighbor imputation also preserves the distribution of the variable and does not reduce the variance. However, k-nearest neighbor imputation may not be feasible if there are many missing values or if there are no similar cases in the dataset. The performance of this technique also depends on the choice of the K value.

# %% [markdown]
# ## ANSWER-3

# %% [markdown]
# 1. **Parentaleducation level:** Students whose parents have higher education levels tend to perform better in exams.
# 2. **Study time:** Students who spend more time studying tend to perform better in exams.
# 3. **Absences:** Students who have higher rates of absences tend to perform worse in exams.
# 4. **Gender:** In some studies, gender has been found to influence student performance, with females performing better than males in some subjects.
#
#
# #### We saw the skewedness of graph either it is left skewed or right skewed.

# %% [markdown]
# ## ANSWER-4

# %% [markdown]
# In the context of the student performance dataset, feature engineering involves identifying the most relevant variables that influence student performance and transforming these variables into a format that is suitable for machine learning algorithms.
#
# To select and transform the variables for our model, we first examined the dataset to identify the most relevant variables. We then performed a series of transformations on the data to create new features and ensure that the data was suitable for machine learning algorithms. Here are the steps we took:
#
# - Data cleaning: We first cleaned the dataset by removing any missing or invalid data points.
# - Feature scaling: We normalized the data using a standard scaler to ensure that all variables had the same scale and were not biased towards one variable.
# - One-hot encoding: We used one-hot encoding to convert categorical variables such as gender and parental education level into numerical variables that could be used in machine learning algorithms.
# - Feature engineering: We created new features such as the grade average of the student, the ratio of free time to study time, and the ratio of failures to total classes to capture additional information that could improve the performance of our model.

# %% [markdown]
# ## ANSWER-5

# %%
wine.hist(figsize=(20,20), grid=0, color='#404040')
plt.show()

# %% [markdown]
# From the histograms, we can see that some features exhibit non-normality, including:
#
# - fixed acidity
# - volatile acidity
# - citric acid
# - residual sugar
# - free sulfur dioxide
# - total sulfur dioxide
# - alcohol
#
# To improve normality, we can apply various transformations to these features. Here are some possible transformations:
#
# - ***Log transformation:*** This can be applied to features with right-skewed distributions, such as residual sugar, free sulfur dioxide, and total sulfur dioxide. The log transformation can help reduce the effect of extreme values and make the distribution more symmetric.
# - ***Square root transformation:*** This can be applied to features with highly skewed distributions, such as volatile acidity and citric acid. The square root transformation can help reduce the skewness and make the distribution more bell-shaped.

# %% [markdown]
# ## ANSWER-6

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
wine_data_std = scaler.fit_transform(wine)

# %%
from sklearn.decomposition import PCA

pca = PCA()
pca.fit(wine_data_std)
# Out:
# PCA()

# %%
explained_variance = pca.explained_variance_ratio_
explained_variance
# Out:
# array([0.26009731, 0.1868235 , 0.14024331, 0.10125174, 0.0811053 ,
#        0.05521602, 0.05152648, 0.04215605, 0.03427563, 0.02732662,
#        0.01501822, 0.00495983])

# %%
explained_variance_percentage=[each_variance*100 for each_variance in explained_variance]
explained_variance_percentage
# Out:
# [26.00973081242582,
#  18.682350358265907,
#  14.024330760914452,
#  10.125173943108006,
#  8.110530168961654,
#  5.521602032656026,
#  5.152648309493781,
#  4.2156046479563605,
#  3.4275628057646426,
#  2.7326616117136657,
#  1.5018219064767202,
#  0.4959826422629685]

# %%
import numpy as np
cumulative_variance = np.cumsum(explained_variance)
n_components = np.argmax(cumulative_variance >= 0.9) + 1

print(f"Minimum number of principal components required to explain 90% of variance: {n_components}")
# Out:
# Minimum number of principal components required to explain 90% of variance: 8
